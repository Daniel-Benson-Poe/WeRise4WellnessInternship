# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel-Benson-Poe/WeRise4WellnessInternship/blob/main/infertilityclinicaltrial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-64991e8b-8096-4df1-bc4f-513498673688" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64991e8b-8096-4df1-bc4f-513498673688">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-fd0c9ff2-d799-4a47-b766-49a6d42b6efd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd0c9ff2-d799-4a47-b766-49a6d42b6efd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
infertility_data_df = pd.read_excel("Infertility-study-data.xlsx", index_col=0)
baseline_data_df = pd.read_excel("infertility-study-data-baseline.xlsx", index_col=0)

# %%
infertility_data_df.head()
# Out:
#                                          Subjects analyzed for oocyte retrieval  \
# Drug (units) administered
# FE 999302 (1 μg) and Follitropin Delta                                      104
# FE 999302 (2 μg) and Follitropin Delta                                      101
# FE 999302 (4 μg) and Follitropin Delta                                       99
# FE 999302 (8 μg) and Follitropin Delta                                      107
# FE 999302 (12 μg) and Follitropin Delta                                     104
#
#                                          Mean number of oocytes retrieved  \
# Drug (units) administered
# FE 999302 (1 μg) and Follitropin Delta                               10.9
# FE 999302 (2 μg) and Follitropin Delta                               10.8
# FE 999302 (4 μg) and Follitropin Delta                               10.8
# FE 999302 (8 μg) and Follitropin Delta                               11.3
# ...

# %%
baseline_data_df.head(10)
# Out:
#                                   FE 999302 (1 μg) and Follitropin Delta  \
# Number of subjects                                                   104
# 30-37 years                                                           73
# 38-42 years                                                           31
# American Indian or Alaska Native                                       1
# Asian                                                                  2
#  Black or African American                                             0
# Multiple                                                               0
# White                                                                101
# Hispanic or Latino                                                     2
# Not Hispanic or Latino                                               102
#
#                                   FE 999302 (2 μg) and Follitropin Delta  \
# Number of subjects                                                   101
# ...

# %% [markdown]
# # Baseline Data

# %% [markdown]
# ## Explore Demographics

# %%
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[0].index, x=baseline_data_df.iloc[0])

# %%
i=1
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=2
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=3
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=4
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=5
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=6
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=7
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=8
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %%
i=9
plt.figure(figsize=(12,6))
sns.barplot(y=baseline_data_df.iloc[i].index, x=baseline_data_df.iloc[i])
plt.show()

# %% [markdown]
# #Statistical Exploration

# %%
i = 0
while(i<6):
  plt.figure(figsize=(12,6))
  sns.barplot(y=infertility_data_df.iloc[i].index, x=infertility_data_df.iloc[i])
  plt.show()
  i += 1

# %%
infertility_data_df.head(10)
# Out:
#                                          Subjects analyzed for oocyte retrieval  \
# Drug (units) administered
# FE 999302 (1 μg) and Follitropin Delta                                      104
# FE 999302 (2 μg) and Follitropin Delta                                      101
# FE 999302 (4 μg) and Follitropin Delta                                       99
# FE 999302 (8 μg) and Follitropin Delta                                      107
# FE 999302 (12 μg) and Follitropin Delta                                     104
# Placebo and Follitropin Delta                                               104
#
#                                          Mean number of oocytes retrieved  \
# Drug (units) administered
# FE 999302 (1 μg) and Follitropin Delta                               10.9
# FE 999302 (2 μg) and Follitropin Delta                               10.8
# FE 999302 (4 μg) and Follitropin Delta                               10.8
# ...

# %%
infertility_data_df.columns
# Out:
# Index(['Subjects analyzed for oocyte retrieval',
#        'Mean number of oocytes retrieved', 'Oocyte retrieval error (+/-)',
#        'Number subjects tested for metaphase II oocytes',
#        'Mean number metaphase II oocytes retrieved',
#        'Mataphase II oocyte retireval error (+/-)',
#        'Number subjects tested for fertilised oocytes',
#        'Mean number fertilized oocytes', 'Firtilised oocyte error (+/-)',
#        'Subjects analyzed for positive BhCG', 'Number positive BhCG subjects',
#        'Subjects analyzed for clinical pregnancy',
#        'Number clinical pregnancies', 'Subjects analyzed for vital pregnancy',
#        'Number vital pregnancies', 'Subjects analyzed for ongoing pregnancy',
#        'Number ongoing pregnancies',
#        'Number subjects affected by serious adverse events',
#        'Number subjects affected by non-serioues adverse events',
#        'Procedural pain', 'Headache', 'Spontaneous Abortion',
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Mean number of oocytes retrieved"].values, y=infertility_data_df["Mean number of oocytes retrieved"].index)
plt.title("Mean number of oocytes retrieved")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Mean number metaphase II oocytes retrieved"].values, y=infertility_data_df["Mean number metaphase II oocytes retrieved"].index)
plt.title("Mean number metaphase II oocytes retrieved")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Mean number fertilized oocytes"].values, y=infertility_data_df["Mean number fertilized oocytes"].index)
plt.title("Mean number fertilized oocytes")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Number positive BhCG subjects"].values, y=infertility_data_df["Mean number fertilized oocytes"].index)
plt.title("Number positive BhCG subjects")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Number clinical pregnancies"].values, y=infertility_data_df["Number clinical pregnancies"].index)
plt.title("Number clinical pregnancies")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Number ongoing pregnancies"].values, y=infertility_data_df["Number ongoing pregnancies"].index)
plt.title("Number ongoing pregnancies")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Number subjects affected by serious adverse events"].values, y=infertility_data_df["Number subjects affected by serious adverse events"].index)
plt.title("Number subjects affected by serious adverse events")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Number subjects affected by non-serioues adverse events"].values, y=infertility_data_df["Number subjects affected by non-serioues adverse events"].index)
plt.title("Number subjects affected by non-serioues adverse events")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Procedural pain"].values, y=infertility_data_df["Procedural pain"].index)
plt.title("Procedural pain")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Headache"].values, y=infertility_data_df["Headache"].index)
plt.title("Headache")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Spontaneous Abortion"].values, y=infertility_data_df["Spontaneous Abortion"].index)
plt.title("Spontaneous Abortion")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Biochemical Pregnancy"].values, y=infertility_data_df["Biochemical Pregnancy"].index)
plt.title("Biochemical Pregnancy")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Nausea"].values, y=infertility_data_df["Nausea"].index)
plt.title("Nausea")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Ovarian Hyperstimulation Syndrome"].values, y=infertility_data_df["Ovarian Hyperstimulation Syndrome"].index)
plt.title("Ovarian Hyperstimulation Syndrome")
plt.plot;

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=infertility_data_df["Nasopharyngitis"].values, y=infertility_data_df["Nasopharyngitis"].index)
plt.title("Nasopharyngitis")
plt.plot;
